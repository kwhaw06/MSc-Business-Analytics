# %%
# load libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# creating fake data
n = np.random.normal(0, 10, 1000)
p = np.random.poisson(10, 1000)

df = pd.DataFrame({'Normal distr.' : n, 'Poisson distr.' : p})
df
# Out:
#      Normal distr.  Poisson distr.
# 0       -12.715008              11
# 1         0.181737              15
# 2        -2.171507              12
# 3       -10.616054              15
# 4        -8.796596              11
# ..             ...             ...
# 995     -10.306120               3
# 996       1.046777               7
# 997      -1.709249              13
# 998      -4.304490              15
# 999     -11.366275               5
#
# [1000 rows x 2 columns]

# %%
# continous vraible case
sns.displot(df, x='Normal distr.')

# %%
# replacing counts with probabilities
sns.displot(df, x='Normal distr.', stat='probability')

# %%
# let's get a kernel density
sns.displot(df, x='Normal distr.', kind='kde', bw_adjust=0.1)

# %%
# discrete variable case
sns.displot(df, x='Poisson distr.', discrete=True)

# %%
df
# Out:
#      Normal distr.  Poisson distr.
# 0       -12.715008              11
# 1         0.181737              15
# 2        -2.171507              12
# 3       -10.616054              15
# 4        -8.796596              11
# ..             ...             ...
# 995     -10.306120               3
# 996       1.046777               7
# 997      -1.709249              13
# 998      -4.304490              15
# 999     -11.366275               5
#
# [1000 rows x 2 columns]

# %%
molten = pd.melt(df, value_name='Score', var_name='Distribution')
molten
# Out:
#         Distribution      Score
# 0      Normal distr. -12.715008
# 1      Normal distr.   0.181737
# 2      Normal distr.  -2.171507
# 3      Normal distr. -10.616054
# 4      Normal distr.  -8.796596
# ...              ...        ...
# 1995  Poisson distr.   3.000000
# 1996  Poisson distr.   7.000000
# 1997  Poisson distr.  13.000000
# 1998  Poisson distr.  15.000000
# 1999  Poisson distr.   5.000000
#
# [2000 rows x 2 columns]

# %%
pd.pivot_table(molten, columns='Distribution', values='Score')
# Out:
# Distribution  Normal distr.  Poisson distr.
# Score             -0.010382           9.986

# %%
# conditioning on a 3rd variable is simple
molten = pd.melt(df, value_name='Score', var_name='Distribution')
sns.displot(molten, x='Score', hue='Distribution', element='step')

# %%
# produicing a bivariate histogram
sns.displot(df, x='Normal distr.', y='Poisson distr.', kind='kde')
